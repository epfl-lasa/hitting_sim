# %%
import pandas as pd

# %%
df1_6 = pd.read_csv('obj1_hit6.csv')
df2_6 = pd.read_csv('obj2_hit6.csv')
df3_6 = pd.read_csv('obj3_hit6.csv')
df1_7 = pd.read_csv('obj1_hit7.csv')
df2_7 = pd.read_csv('obj2_hit7.csv')
df3_7 = pd.read_csv('obj3_hit7.csv')

JointPos16 = df1_6['JointPos'].to_numpy()

# %%
JointPos16[0][0]
# Out:
# '['
