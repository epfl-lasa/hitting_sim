# %%
import numpy as np
import os
import time
import pybullet as p
import pybullet_data
import scipy
import math
import matplotlib.pyplot as plt

from get_robot_iiwa import sim_robot
import pandas
# Out:
# pybullet build time: Oct 14 2023 15:43:53

# %%
################## GET THE OBJECTS ######################################

path_folder = '/home/harshit/developments/Robot_joint_data/'
PAD = "processedActualData"
PAD = os.path.join(path_folder, PAD + ".csv")

data = pandas.read_csv(PAD, header=0)
#############################################################################

# %%
data.loc[:,['J1', 'J2', 'J3', 'J4', 'J6', 'J7']]
# Out:
#                J1        J2        J3        J4        J6        J7
# 0       -0.000279  0.009227  0.007376 -0.001363  0.018713  0.003784
# 1       -0.000278  0.009463  0.007459 -0.001389  0.019002  0.003808
# 2       -0.000276  0.009695  0.007544 -0.001407  0.019288  0.003834
# 3       -0.000275  0.009921  0.007631 -0.001421  0.019570  0.003859
# 4       -0.000273  0.010142  0.007722 -0.001430  0.019860  0.003884
# ...           ...       ...       ...       ...       ...       ...
# 2157812 -0.167679  0.527176 -0.471638  0.482367 -0.044926 -0.315675
# 2157813 -0.166771  0.526379 -0.472934  0.482840 -0.043714 -0.312211
# 2157814 -0.164972  0.524799 -0.475528  0.483761 -0.041265 -0.305243
# 2157815 -0.163186  0.523215 -0.478147  0.484686 -0.038805 -0.298280
# 2157816 -0.161402  0.521608 -0.480781  0.485604 -0.036350 -0.291379
#
# [2157817 rows x 6 columns]

# %%
a = data.iloc[:, 1:8].values

# %%
df = pandas.DataFrame({'X2': np.array([0,0,0])}, index = [0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df = pandas.DataFrame({'X2': np.array([0,0,0])}, index = [0])
#
# File ~/software/anaconda3/envs/robotics_python/lib/python3.10/site-packages/pandas/core/frame.py:767, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     761     mgr = self._init_mgr(
#     762         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     763     )
#     765 elif isinstance(data, dict):
#     766     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 767     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     768 elif isinstance(data, ma.MaskedArray):
#     769     from numpy.ma import mrecords
#
# ...

# %%
df

# %%
robot = sim_robot(0, 1)

v_dir = np.array([0, 1, 0])

for i in range(2):
    robot.set_to_joint_position(a[i])
    X2 = robot.get_joint_cartesian_position(2)
    df.iloc[-1] = X2
